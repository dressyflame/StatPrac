# %%
# Import necessary packages
import os
import numpy as np
import warnings
from scipy.io import wavfile
from python_speech_features import mfcc
from hmmlearn import hmm
from pydub import AudioSegment
from pydub.silence import split_on_silence
import joblib
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
# Function to detect leading silence in an audio segment
def detect_leading_silence(sound, silence_threshold=-50.0, chunk_size=10):
    '''
    sound is a pydub.AudioSegment
    silence_threshold in dB
    chunk_size in ms

    Iterate over chunks until you find the first one with sound.
    '''
    trim_ms = 0  # in milliseconds

    assert chunk_size > 0  # to avoid infinite loop
    while trim_ms < len(sound) and sound[trim_ms:trim_ms+chunk_size].dBFS < silence_threshold:
        trim_ms += chunk_size

    return trim_ms

# %%
# Define the ModelHMM class for Hidden Markov Models
class ModelHMM(object):
    def __init__(self, num_components=8, num_iter=1000):
        self.n_components = num_components
        self.n_iter = num_iter
        # Define the covariance type and the type of HMM
        self.cov_type = 'diag'
        self.model_name = 'GaussianHMM'
        # Initialize the variable in which we will store the models for each word
        self.models = []
        # Define the model using the specified parameters
        self.model = hmm.GaussianHMM(n_components=self.n_components,
                                     covariance_type=self.cov_type, n_iter=self.n_iter)

    # Define a method to train the model
    # 'training_data' is a 2D numpy array where each row has length of number of mfcc coefficients
    def train(self, training_data):
        np.seterr(all='ignore')
        cur_model = self.model.fit(training_data)
        self.models.append(cur_model)

    # Define a method to compute log likelihood score for input features
    def compute_score(self, input_data):
        return self.model.score(input_data)  # model.score returns log likelihood of sample input_data

# %%
# Function to build one model for a digit
def build_one_model(input_folder, num_states, num_cep_coeff):
    # input_folder: path to the folder containing training wav files with the word
    # num_states: number of hidden states in HMM
    # num_cep_coeff: number of MFCC features extracted from each time window
    X = np.array([])  # features
    training_files = [x for x in os.listdir(input_folder) if x.endswith('.wav')]
    for filename in training_files:
        # Extract the current filepath and read the file
        filepath = os.path.join(input_folder, filename)
        sound = AudioSegment.from_file(filepath, format="wav")
        duration = len(sound)

        start_trim = detect_leading_silence(sound)
        end_trim = detect_leading_silence(sound.reverse())
        trimmed_sound = sound[start_trim:duration - end_trim]
        trimmed_duration = len(trimmed_sound)  # in milliseconds

        # Check if the trimmed sound is shorter than 150 ms
        if trimmed_duration < 150:
            continue  # skip this file

        # Get the samples from trimmed_sound
        signal = np.array(trimmed_sound.get_array_of_samples())
        if trimmed_sound.channels == 2:
            signal = signal.reshape((-1, 2))
            # Convert to mono by averaging the channels
            signal = signal.mean(axis=1)
        signal = signal.astype(np.float32)
        sampling_freq = trimmed_sound.frame_rate

        # Extract features
        # Default values:
        # winlen=0.025, winstep=0.01, nfft=512,
        with warnings.catch_warnings():
            warnings.simplefilter('ignore')
            features_mfcc = mfcc(signal, sampling_freq, numcep=num_cep_coeff)

        # Append features to the variable X
        if len(X) == 0:
            X = features_mfcc
        else:
            X = np.append(X, features_mfcc, axis=0)

    # Check if we have collected any features
    if len(X) == 0:
        print(f"No valid audio files found in {input_folder}.")
        return None, None, num_cep_coeff

    # Initiate HMM model object
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore', category=DeprecationWarning)
        model = ModelHMM(num_components=num_states)

    # Train HMM model, calculate likelihood of the sample by the trained model
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore', category=DeprecationWarning)
        model.train(X)
        model_score = model.compute_score(X)

    return model, model_score, num_cep_coeff

# %%
# Function to build models for all digits
def build_models(input_folder):
    # input_folder contains subfolders with samples of words in wav files

    # Initialize the variable to store all the models
    speech_models = []

    # Parse the input directory
    for dirname in os.listdir(input_folder):

        # Get name of subfolder
        subfolder = os.path.join(input_folder, dirname)

        if not os.path.isdir(subfolder):
            continue

        # Extract label
        label = subfolder[subfolder.rfind(os.sep) + 1:]

        # Fit model for label
        model = build_one_model(subfolder, num_states=num_components, num_cep_coeff=num_cepstr)

        # If model building was successful, add to list
        if model[0] is not None:
            # Add the model to the list
            speech_models.append((model, label))
            print(f"Fitted model for {label}")
        else:
            print(f"Failed to build model for {label}")

        # Reset model variable
        model = None

    return speech_models

# %%
# Set parameters
input_folder = "./MNIST_9-25"
num_components = 17
num_cepstr = 17

# Build models for all digits and save them
speech_models = build_models(input_folder)

# Save the trained models to a file
joblib.dump(speech_models, 'saved_models.pkl')
print("Models saved to 'saved_models.pkl'")
# Out:
# Fitted model for num5
# Fitted model for num6
# Fitted model for num8
# Fitted model for num3
# Fitted model for num2
# Fitted model for num4
# Fitted model for num7
# Fitted model for num1
# Fitted model for num9
# Fitted model for num0
# Models saved to 'saved_models.pkl'

# %%
# Load the saved models
speech_models = joblib.load('saved_models.pkl')
print("Models loaded from 'saved_models.pkl'")
# Out:
# Models loaded from 'saved_models.pkl'

# %%
# Function to split an audio file into 10 digits
def split_audio_into_digits(sound_file):
    """
    Splits the audio file into chunks corresponding to individual digits.
    Adjusts min_silence_len and silence_thresh to get exactly 10 chunks.
    """
    min_silence_len = 50  # starting value
    silence_thresh = -40  # starting value

    # Try different combinations to get exactly 10 chunks
    for silence_thresh in range(-30, -61, -1):
        for min_silence_len in range(50, 500, 10):
            audio_chunks = split_on_silence(sound_file,
                                            min_silence_len=min_silence_len,
                                            silence_thresh=silence_thresh)
            if len(audio_chunks) == 10:
                return audio_chunks
    # If unable to get exactly 10 chunks, return the best attempt
    print(f"Could not split audio into 10 chunks. Got {len(audio_chunks)} chunks.")
    return audio_chunks

# %%
# Function to predict the digit for a given audio chunk
def predict_digit(chunk, speech_models):
    """
    Predicts the digit corresponding to the given audio chunk.
    """
    # Trim leading and trailing silence from the chunk
    start_trim = detect_leading_silence(chunk)
    end_trim = detect_leading_silence(chunk.reverse())
    duration = len(chunk)
    trimmed_chunk = chunk[start_trim:duration - end_trim]
    trimmed_duration = len(trimmed_chunk)

    # Check if the trimmed sound is shorter than 150 ms
    if trimmed_duration < 150:
        # Return empty string or a placeholder
        return ''

    # Get the samples from trimmed_chunk
    signal = np.array(trimmed_chunk.get_array_of_samples())
    if trimmed_chunk.channels == 2:
        signal = signal.reshape((-1, 2))
        # Convert to mono by averaging the channels
        signal = signal.mean(axis=1)
    signal = signal.astype(np.float32)
    sampling_freq = trimmed_chunk.frame_rate

    # Extract features
    num_cep_coeff = speech_models[0][0][2]  # Assuming all models have the same num_cep_coeff
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        features_mfcc = mfcc(signal, sampling_freq, numcep=num_cep_coeff)

    # Compute scores for each model
    max_score = -float('inf')
    predicted_label = None
    for model, label in speech_models:
        model_hmm = model[0]  # model is a tuple (ModelHMM object, model_score, num_cep_coeff)
        try:
            score = model_hmm.compute_score(features_mfcc)
        except Exception as e:
            # If scoring fails, assign a very low score
            score = -float('inf')
        if score > max_score:
            max_score = score
            predicted_label = label

    if predicted_label is not None:
        digit = predicted_label.replace('num', '')
    else:
        digit = ''

    return digit

# %%
import glob

# %%
# Process the test audio files and predict phone numbers
var = 6
test_folder = f'./test/{var}'
test_files = glob.glob(f"./test/{var}/*.wav")
# Extract indices and sort the files
test_files_sorted = sorted(test_files, key=lambda f: int(f.split('/')[-1].split('.')[0]))
print(test_files_sorted)

results = []

for filename in test_files_sorted:
    # Extract the index from the filename
    # index = int(os.path.splitext(filename)[0])
    # Process the file
    filepath = filename
    # Load the audio file
    sound_file = AudioSegment.from_wav(filepath)
    # Split the audio into chunks corresponding to digits
    audio_chunks = split_audio_into_digits(sound_file)
    # Check if we have exactly 10 chunks
    if len(audio_chunks) != 10:
        print(f"Warning: File {filename} was split into {len(audio_chunks)} chunks instead of 10.")
    # Process each chunk
    phone_number = ''
    for chunk in audio_chunks:
        # Get the predicted digit for each chunk
        predicted_digit = predict_digit(chunk, speech_models)
        phone_number += predicted_digit
    # Ensure phone_number is 10 digits
    if len(phone_number) != 10:
        print(f"Warning: Phone number from file {filename} is {len(phone_number)} digits instead of 10.")
    # Store the result
    results.append(phone_number)
    print(f"Processed file {filename}: {phone_number}")
# Out:
# ['./test/6/0.wav', './test/6/1.wav', './test/6/2.wav', './test/6/3.wav', './test/6/4.wav', './test/6/5.wav', './test/6/6.wav', './test/6/7.wav', './test/6/8.wav', './test/6/9.wav', './test/6/10.wav', './test/6/11.wav', './test/6/12.wav', './test/6/13.wav', './test/6/14.wav', './test/6/15.wav', './test/6/16.wav', './test/6/17.wav', './test/6/18.wav', './test/6/19.wav', './test/6/20.wav', './test/6/21.wav', './test/6/22.wav', './test/6/23.wav', './test/6/24.wav', './test/6/25.wav', './test/6/26.wav', './test/6/27.wav', './test/6/28.wav', './test/6/29.wav', './test/6/30.wav', './test/6/31.wav', './test/6/32.wav', './test/6/33.wav', './test/6/34.wav', './test/6/35.wav', './test/6/36.wav', './test/6/37.wav', './test/6/38.wav', './test/6/39.wav', './test/6/40.wav', './test/6/41.wav', './test/6/42.wav', './test/6/43.wav', './test/6/44.wav', './test/6/45.wav', './test/6/46.wav', './test/6/47.wav', './test/6/48.wav', './test/6/49.wav', './test/6/50.wav', './test/6/51.wav', './test/6/52.wav', './test/6/53.wav', './test/6/54.wav', './test/6/55.wav', './test/6/56.wav', './test/6/57.wav', './test/6/58.wav', './test/6/59.wav', './test/6/60.wav', './test/6/61.wav', './test/6/62.wav', './test/6/63.wav', './test/6/64.wav', './test/6/65.wav', './test/6/66.wav', './test/6/67.wav', './test/6/68.wav', './test/6/69.wav', './test/6/70.wav', './test/6/71.wav', './test/6/72.wav', './test/6/73.wav', './test/6/74.wav', './test/6/75.wav', './test/6/76.wav', './test/6/77.wav', './test/6/78.wav', './test/6/79.wav', './test/6/80.wav', './test/6/81.wav', './test/6/82.wav', './test/6/83.wav', './test/6/84.wav', './test/6/85.wav', './test/6/86.wav', './test/6/87.wav', './test/6/88.wav', './test/6/89.wav', './test/6/90.wav', './test/6/91.wav', './test/6/92.wav', './test/6/93.wav', './test/6/94.wav', './test/6/95.wav', './test/6/96.wav', './test/6/97.wav', './test/6/98.wav', './test/6/99.wav', './test/6/100.wav', './test/6/101.wav', './test/6/102.wav', './test/6/103.wav', './test/6/104.wav', './test/6/105.wav', './test/6/106.wav', './test/6/107.wav', './test/6/108.wav', './test/6/109.wav', './test/6/110.wav', './test/6/111.wav', './test/6/112.wav', './test/6/113.wav', './test/6/114.wav', './test/6/115.wav', './test/6/116.wav', './test/6/117.wav', './test/6/118.wav', './test/6/119.wav', './test/6/120.wav', './test/6/121.wav', './test/6/122.wav', './test/6/123.wav', './test/6/124.wav', './test/6/125.wav', './test/6/126.wav', './test/6/127.wav', './test/6/128.wav', './test/6/129.wav', './test/6/130.wav', './test/6/131.wav', './test/6/132.wav', './test/6/133.wav', './test/6/134.wav', './test/6/135.wav', './test/6/136.wav', './test/6/137.wav', './test/6/138.wav', './test/6/139.wav', './test/6/140.wav', './test/6/141.wav', './test/6/142.wav', './test/6/143.wav', './test/6/144.wav', './test/6/145.wav', './test/6/146.wav', './test/6/147.wav', './test/6/148.wav', './test/6/149.wav', './test/6/150.wav', './test/6/151.wav', './test/6/152.wav', './test/6/153.wav', './test/6/154.wav', './test/6/155.wav', './test/6/156.wav', './test/6/157.wav', './test/6/158.wav', './test/6/159.wav', './test/6/160.wav', './test/6/161.wav', './test/6/162.wav', './test/6/163.wav', './test/6/164.wav', './test/6/165.wav', './test/6/166.wav', './test/6/167.wav', './test/6/168.wav', './test/6/169.wav', './test/6/170.wav', './test/6/171.wav', './test/6/172.wav', './test/6/173.wav', './test/6/174.wav', './test/6/175.wav', './test/6/176.wav', './test/6/177.wav', './test/6/178.wav', './test/6/179.wav', './test/6/180.wav', './test/6/181.wav', './test/6/182.wav', './test/6/183.wav', './test/6/184.wav', './test/6/185.wav', './test/6/186.wav', './test/6/187.wav', './test/6/188.wav', './test/6/189.wav', './test/6/190.wav', './test/6/191.wav', './test/6/192.wav', './test/6/193.wav', './test/6/194.wav', './test/6/195.wav', './test/6/196.wav', './test/6/197.wav', './test/6/198.wav', './test/6/199.wav', './test/6/200.wav', './test/6/201.wav', './test/6/202.wav', './test/6/203.wav', './test/6/204.wav', './test/6 ...
# Warning: Phone number from file ./test/6/0.wav is 9 digits instead of 10.
# Processed file ./test/6/0.wav: 838023822
# Processed file ./test/6/1.wav: 0063546716
# Processed file ./test/6/2.wav: 0745764654
# Processed file ./test/6/3.wav: 4867074409
# Processed file ./test/6/4.wav: 4571876580
# Processed file ./test/6/5.wav: 4747455362
# Processed file ./test/6/6.wav: 8090667718
# Processed file ./test/6/7.wav: 7785915329
# Processed file ./test/6/8.wav: 3679667325
# Processed file ./test/6/9.wav: 1711475965
# Processed file ./test/6/10.wav: 8505465004
# Processed file ./test/6/11.wav: 3662310940
# Processed file ./test/6/12.wav: 4397389867
# Processed file ./test/6/13.wav: 5937394544
# Processed file ./test/6/14.wav: 2377752945
# Processed file ./test/6/15.wav: 8549683433
# Processed file ./test/6/16.wav: 5865776428
# Processed file ./test/6/17.wav: 5482324943
# Processed file ./test/6/18.wav: 4096392542
# Warning: Phone number from file ./test/6/19.wav is 9 digits instead of 10.
# Processed file ./test/6/19.wav: 752015148
# Processed file ./test/6/20.wav: 9220981149
# Warning: Phone number from file ./test/6/21.wav is 9 digits instead of 10.
# Processed file ./test/6/21.wav: 423438553
# Processed file ./test/6/22.wav: 5266579404
# Processed file ./test/6/23.wav: 1477775042
# Processed file ./test/6/24.wav: 6417329801
# Processed file ./test/6/25.wav: 9640812170
# Processed file ./test/6/26.wav: 8413811252
# Processed file ./test/6/27.wav: 8084776262
# Processed file ./test/6/28.wav: 6480194418
# Processed file ./test/6/29.wav: 5537178877
# Processed file ./test/6/30.wav: 0380807379
# Processed file ./test/6/31.wav: 0666742228
# Processed file ./test/6/32.wav: 4595386775
# Processed file ./test/6/33.wav: 5734395806
# Processed file ./test/6/34.wav: 2911098946
# Processed file ./test/6/35.wav: 4295547086
# Processed file ./test/6/36.wav: 1440907378
# Processed file ./test/6/37.wav: 3177118304
# Processed file ./test/6/38.wav: 3088845283
# Processed file ./test/6/39.wav: 0902732044
# Processed file ./test/6/40.wav: 2081684465
# Processed file ./test/6/41.wav: 4946456921
# Processed file ./test/6/42.wav: 9309995777
# Processed file ./test/6/43.wav: 6519939484
# Processed file ./test/6/44.wav: 9347497558
# Processed file ./test/6/45.wav: 2314888382
# Processed file ./test/6/46.wav: 5756255948
# Processed file ./test/6/47.wav: 2734246803
# Processed file ./test/6/48.wav: 2975953047
# Processed file ./test/6/49.wav: 4283439839
# Processed file ./test/6/50.wav: 8613743215
# Warning: Phone number from file ./test/6/51.wav is 9 digits instead of 10.
# Processed file ./test/6/51.wav: 348321029
# Processed file ./test/6/52.wav: 3373004913
# Processed file ./test/6/53.wav: 8510665573
# Processed file ./test/6/54.wav: 5431747192
# Processed file ./test/6/55.wav: 5852445547
# Warning: Phone number from file ./test/6/56.wav is 9 digits instead of 10.
# Processed file ./test/6/56.wav: 506534882
# Processed file ./test/6/57.wav: 4329435538
# Processed file ./test/6/58.wav: 7828078649
# Processed file ./test/6/59.wav: 4156779815
# Processed file ./test/6/60.wav: 1592570875
# Processed file ./test/6/61.wav: 0464518113
# Processed file ./test/6/62.wav: 1641751561
# Processed file ./test/6/63.wav: 3633535145
# Processed file ./test/6/64.wav: 7932431470
# Processed file ./test/6/65.wav: 1442417857
# Processed file ./test/6/66.wav: 7149322383
# Processed file ./test/6/67.wav: 7936651427
# Processed file ./test/6/68.wav: 8971929991
# Processed file ./test/6/69.wav: 0718837356
# Processed file ./test/6/70.wav: 9696779558
# Processed file ./test/6/71.wav: 4464273558
# Processed file ./test/6/72.wav: 8558538874
# Processed file ./test/6/73.wav: 8679538869
# Processed file ./test/6/74.wav: 1307744040
# Processed file ./test/6/75.wav: 0672355183
# Processed file ./test/6/76.wav: 4771338321
# Processed file ./test/6/77.wav: 2718238245
# Processed file ./test/6/78.wav: 9221006090
# Processed file ./test/6/79.wav: 9678829981
# Warning: Phone number from file ./test/6/80.wav is 9 digits instead of 10.
# Processed file ./test/6/80.wav: 941524572
# Processed file ./test/6/81.wav: 3323377556
# Processed file ./test/6/82.wav: 3441377347
# Processed file ./test/6/83.wav: 3397796500
# Processed file ./test/6/84.wav: 5782730047
# Processed file ./test/6/85.wav: 7071413020
# Processed file ./test/6/86.wav: 4015577334
# Processed file ./test/6/87.wav: 6317876876
# Processed file ./test/6/88.wav: 5148892203
# Processed file ./test/6/89.wav: 7044938581
# Processed file ./test/6/90.wav: 4965852764
# Processed file ./test/6/91.wav: 1191157759
# Processed file ./test/6/92.wav: 9933653812
# Processed file ./test/6/93.wav: 1078957738
# Processed file ./test/6/94.wav: 8952570485
# Processed file ./test/6/95.wav: 2124541777
# Processed file ./test/6/96.wav: 4812135285
# Processed file ./test/6/97.wav: 9115890693
# Processed file ./test/6/98.wav: 0638245622
# Processed file ./test/6/99.wav: 7914073177
# Warning: Phone number from file ./test/6/100.wav is 9 digits instead of 10.
# Processed file ./test/6/100.wav: 948374057
# Processed file ./test/6/101.wav: 5686541335
# Processed file ./test/6/102.wav: 5657543608
# Processed file ./test/6/103.wav: 9345799770
# Processed file ./test/6/104.wav: 7677358664
# Processed file ./test/6/105.wav: 2217782672
# Processed file ./test/6/106.wav: 8686426949
# Processed file ./test/6/107.wav: 1453336560
# Processed file ./test/6/108.wav: 7389296952
# Processed file ./test/6/109.wav: 5758675177
# Processed file ./test/6/110.wav: 2215210377
# Processed file ./test/6/111.wav: 7863148743
# Processed file ./test/6/112.wav: 8401859973
# Warning: Phone number from file ./test/6/113.wav is 9 digits instead of 10.
# Processed file ./test/6/113.wav: 838330299
# Warning: Phone number from file ./test/6/114.wav is 9 digits instead of 10.
# Processed file ./test/6/114.wav: 290977120
# Processed file ./test/6/115.wav: 2242953398
# Processed file ./test/6/116.wav: 3423335557
# Processed file ./test/6/117.wav: 7895997745
# Processed file ./test/6/118.wav: 6838889636
# Processed file ./test/6/119.wav: 8112786778
# Processed file ./test/6/120.wav: 3148465955
# Processed file ./test/6/121.wav: 6636719116
# Processed file ./test/6/122.wav: 5849978591
# Processed file ./test/6/123.wav: 7353313394
# Processed file ./test/6/124.wav: 7757778043
# Processed file ./test/6/125.wav: 3089625288
# Processed file ./test/6/126.wav: 4380010655
# Warning: Phone number from file ./test/6/127.wav is 9 digits instead of 10.
# Processed file ./test/6/127.wav: 788734259
# Processed file ./test/6/128.wav: 8899319534
# Warning: Phone number from file ./test/6/129.wav is 9 digits instead of 10.
# Processed file ./test/6/129.wav: 033053507
# Warning: Phone number from file ./test/6/130.wav is 9 digits instead of 10.
# Processed file ./test/6/130.wav: 232841359
# Processed file ./test/6/131.wav: 6677713304
# Warning: Phone number from file ./test/6/132.wav is 9 digits instead of 10.
# Processed file ./test/6/132.wav: 832301195
# Processed file ./test/6/133.wav: 3228325689
# Processed file ./test/6/134.wav: 4329668048
# Processed file ./test/6/135.wav: 1499806080
# Processed file ./test/6/136.wav: 4067149120
# Processed file ./test/6/137.wav: 9478486770
# Processed file ./test/6/138.wav: 0019247231
# Processed file ./test/6/139.wav: 2765477937
# Processed file ./test/6/140.wav: 5768362903
# Processed file ./test/6/141.wav: 8683736319
# Processed file ./test/6/142.wav: 1483007751
# Warning: Phone number from file ./test/6/143.wav is 8 digits instead of 10.
# Processed file ./test/6/143.wav: 89277335
# Warning: Phone number from file ./test/6/144.wav is 8 digits instead of 10.
# Processed file ./test/6/144.wav: 40577259
# Processed file ./test/6/145.wav: 9379648983
# Processed file ./test/6/146.wav: 8379641991
# Processed file ./test/6/147.wav: 6889869815
# Processed file ./test/6/148.wav: 9925277397
# Processed file ./test/6/149.wav: 0998335889
# Processed file ./test/6/150.wav: 2012100206
# Processed file ./test/6/151.wav: 4411155405
# Processed file ./test/6/152.wav: 7312710874
# Processed file ./test/6/153.wav: 6658899931
# Warning: Phone number from file ./test/6/154.wav is 8 digits instead of 10.
# Processed file ./test/6/154.wav: 34349823
# Processed file ./test/6/155.wav: 5436696157
# Processed file ./test/6/156.wav: 9275705178
# Processed file ./test/6/157.wav: 8317469311
# Processed file ./test/6/158.wav: 5118117421
# Processed file ./test/6/159.wav: 0800246151
# Processed file ./test/6/160.wav: 7763709388
# Processed file ./test/6/161.wav: 1478371214
# Processed file ./test/6/162.wav: 9262356474
# Processed file ./test/6/163.wav: 5658942990
# Processed file ./test/6/164.wav: 1688055800
# Processed file ./test/6/165.wav: 0052432503
# Warning: Phone number from file ./test/6/166.wav is 9 digits instead of 10.
# Processed file ./test/6/166.wav: 648131917
# Processed file ./test/6/167.wav: 6100597102
# Processed file ./test/6/168.wav: 2708000115
# Processed file ./test/6/169.wav: 1194377914
# Processed file ./test/6/170.wav: 2157652818
# Processed file ./test/6/171.wav: 5958960966
# Processed file ./test/6/172.wav: 8952453332
# Processed file ./test/6/173.wav: 5146229718
# Processed file ./test/6/174.wav: 1881180988
# Processed file ./test/6/175.wav: 1556557581
# Processed file ./test/6/176.wav: 9864015472
# Processed file ./test/6/177.wav: 5373599861
# Processed file ./test/6/178.wav: 2406095688
# Processed file ./test/6/179.wav: 7774413011
# Warning: Phone number from file ./test/6/180.wav is 9 digits instead of 10.
# Processed file ./test/6/180.wav: 248070824
# Processed file ./test/6/181.wav: 9208031261
# Processed file ./test/6/182.wav: 2283170191
# Processed file ./test/6/183.wav: 1393188798
# Processed file ./test/6/184.wav: 4115273874
# Processed file ./test/6/185.wav: 1513368981
# Processed file ./test/6/186.wav: 4577802809
# Processed file ./test/6/187.wav: 7500731877
# Processed file ./test/6/188.wav: 3669940558
# Processed file ./test/6/189.wav: 3632985864
# Processed file ./test/6/190.wav: 3804881771
# Processed file ./test/6/191.wav: 8925872103
# Processed file ./test/6/192.wav: 8597148199
# Processed file ./test/6/193.wav: 1945707169
# Processed file ./test/6/194.wav: 6367479467
# Warning: Phone number from file ./test/6/195.wav is 9 digits instead of 10.
# Processed file ./test/6/195.wav: 331811432
# Processed file ./test/6/196.wav: 6619039734
# Processed file ./test/6/197.wav: 5640199095
# Processed file ./test/6/198.wav: 0511721259
# Processed file ./test/6/199.wav: 5442498584
# Processed file ./test/6/200.wav: 6960939300
# Processed file ./test/6/201.wav: 5489013717
# Processed file ./test/6/202.wav: 7836544190
# Processed file ./test/6/203.wav: 8383041173
# Processed file ./test/6/204.wav: 6957452092
# Processed file ./test/6/205.wav: 8471511695
# Processed file ./test/6/206.wav: 0878357923
# Processed file ./test/6/207.wav: 5088217395
# Processed file ./test/6/208.wav: 5488521630
# Processed file ./test/6/209.wav: 0936415899
# Processed file ./test/6/210.wav: 7083332078
# Processed file ./test/6/211.wav: 6833005583
# Processed file ./test/6/212.wav: 0370176953
# Processed file ./test/6/213.wav: 4646708728
# Processed file ./test/6/214.wav: 4627841958
# Processed file ./test/6/215.wav: 2988598871
# Processed file ./test/6/216.wav: 0820914033
# Processed file ./test/6/217.wav: 2789895668
# Processed file ./test/6/218.wav: 5361012059
# Processed file ./test/6/219.wav: 8975933937
# Processed file ./test/6/220.wav: 2878679369
# Processed file ./test/6/221.wav: 1890558144
# Processed file ./test/6/222.wav: 9042202782
# Processed file ./test/6/223.wav: 1812793971
# Processed file ./test/6/224.wav: 0976548076
# Processed file ./test/6/225.wav: 5559394748
# Processed file ./test/6/226.wav: 2426344738
# Warning: Phone number from file ./test/6/227.wav is 8 digits instead of 10.
# Processed file ./test/6/227.wav: 54017730
# Processed file ./test/6/228.wav: 9681227106
# Processed file ./test/6/229.wav: 5218641419
# Processed file ./test/6/230.wav: 6433032946
# Processed file ./test/6/231.wav: 5880778314
# Processed file ./test/6/232.wav: 4305251445
# Processed file ./test/6/233.wav: 2973418840
# Processed file ./test/6/234.wav: 2018018272
# Processed file ./test/6/235.wav: 6306943819
# Processed file ./test/6/236.wav: 5810181110
# Processed file ./test/6/237.wav: 5725989777
# Processed file ./test/6/238.wav: 9937727176
# Processed file ./test/6/239.wav: 0595981075
# Processed file ./test/6/240.wav: 4235673774
# Warning: Phone number from file ./test/6/241.wav is 9 digits instead of 10.
# Processed file ./test/6/241.wav: 159534170
# Processed file ./test/6/242.wav: 0969792859
# Warning: Phone number from file ./test/6/243.wav is 9 digits instead of 10.
# Processed file ./test/6/243.wav: 696261710
# Processed file ./test/6/244.wav: 8647895757
# Processed file ./test/6/245.wav: 8193972122
# Processed file ./test/6/246.wav: 3887380158
# Processed file ./test/6/247.wav: 0979839653
# Warning: Phone number from file ./test/6/248.wav is 9 digits instead of 10.
# Processed file ./test/6/248.wav: 339937753
# Processed file ./test/6/249.wav: 4189030893
# Processed file ./test/6/250.wav: 4507922231
# Processed file ./test/6/251.wav: 8829632714
# Processed file ./test/6/252.wav: 8984060871
# Processed file ./test/6/253.wav: 8456592381
# Processed file ./test/6/254.wav: 1599772918
# Processed file ./test/6/255.wav: 6987516876
# Processed file ./test/6/256.wav: 5505214354
# Processed file ./test/6/257.wav: 2057132133
# Processed file ./test/6/258.wav: 8753738817
# Processed file ./test/6/259.wav: 6058569732
# Processed file ./test/6/260.wav: 4135124577
# Processed file ./test/6/261.wav: 1946662535
# Processed file ./test/6/262.wav: 5307238758
# Processed file ./test/6/263.wav: 0772995336
# Processed file ./test/6/264.wav: 8503739787
# Processed file ./test/6/265.wav: 4778832582
# Processed file ./test/6/266.wav: 1891579331
# Warning: Phone number from file ./test/6/267.wav is 9 digits instead of 10.
# Processed file ./test/6/267.wav: 085447711
# Processed file ./test/6/268.wav: 4991922937
# Processed file ./test/6/269.wav: 3839757212
# Processed file ./test/6/270.wav: 8021568755
# Processed file ./test/6/271.wav: 5699398215
# Processed file ./test/6/272.wav: 2449843558
# Processed file ./test/6/273.wav: 5167728438
# Processed file ./test/6/274.wav: 0916536898
# Processed file ./test/6/275.wav: 7491513434
# Processed file ./test/6/276.wav: 9174748328
# Processed file ./test/6/277.wav: 8833287457
# Processed file ./test/6/278.wav: 5944375716
# Processed file ./test/6/279.wav: 0288819167
# Processed file ./test/6/280.wav: 7378491683
# Processed file ./test/6/281.wav: 5862635313
# Processed file ./test/6/282.wav: 1424361242
# Processed file ./test/6/283.wav: 2395858375
# Processed file ./test/6/284.wav: 4985545199
# Processed file ./test/6/285.wav: 2875363480
# Processed file ./test/6/286.wav: 3793577193
# Processed file ./test/6/287.wav: 2441173483
# Processed file ./test/6/288.wav: 6298816922
# Processed file ./test/6/289.wav: 5445041632
# Processed file ./test/6/290.wav: 7053899981
# Warning: Phone number from file ./test/6/291.wav is 9 digits instead of 10.
# Processed file ./test/6/291.wav: 232187170
# Processed file ./test/6/292.wav: 3246569552
# Processed file ./test/6/293.wav: 0042959090
# Processed file ./test/6/294.wav: 0762002816
# Warning: Phone number from file ./test/6/295.wav is 9 digits instead of 10.
# Processed file ./test/6/295.wav: 156755233
# Processed file ./test/6/296.wav: 3427429921
# Processed file ./test/6/297.wav: 7789506492
# Processed file ./test/6/298.wav: 6612911249
# Processed file ./test/6/299.wav: 4714996167

# %%
import pandas as pd

# %%
pd.Series(results).to_csv('result1.csv', header=False)
